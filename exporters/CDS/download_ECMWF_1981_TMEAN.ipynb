# %%
# %matplotlib inline

# %%
import cdsapi
import os
import urllib
import pathlib
import argparse
from datetime import datetime
import multiprocessing
from multiprocessing.pool import Pool

# %%
import numpy as np
import pandas as pd
import xarray as xr

# %%
# grib_params = {'engine':'cfgrib', 'backend_kwargs':{'indexpath':''}}

# %%
dates = pd.date_range(start='1983-09-01', end='2019-12-01', freq='MS')

# %%
opath = pathlib.Path('/media/nicolasf/END19101/data/GCMs/downloads/ECMWF/TMEAN/')

# %%
if not opath.exists():
    opath.mkdir(parents=True)

# %%
c = cdsapi.Client(timeout=60, sleep_max=30)

# %%
for date in dates: 
    
    year = date.year 
    
    month = date.month 
    
    print(f"downloading and processing {year} {str(month).zfill(2)}")
    
    for step in range(1, 7):
        
        data = c.retrieve(
            'seasonal-monthly-single-levels',
            {
                'originating_centre': 'ecmwf',
                'system': '5',
                'variable': '2m_temperature',
                'product_type': 'monthly_mean',
                'year': str(year),
                'month': str(month).zfill(2),
                'leadtime_month': str(step),
                'format': 'netcdf',
            },
            f'{str(opath)}/download_{step}.nc')
        
        data.delete()
    
    lfiles = list(opath.glob("download_?.nc"))
    
    lfiles.sort()
    
    dset = xr.open_mfdataset(lfiles, concat_dim=['time'], combine='nested') 
    
    dset = dset.rename({'time':'step'})
    
    dset['time'] = (('time'), [datetime(year,month,1)])
    
    dset.to_netcdf(opath.joinpath(f'CDS_ECMWF_TMEAN_{year}_{str(month).zfill(2)}.nc'))
    
    if opath.joinpath(f'CDS_ECMWF_TMEAN_{year}_{str(month).zfill(2)}.nc').exists(): 
        print(f"{str(opath.joinpath(f'CDS_ECMWF_TMEAN_{year}_{str(month).zfill(2)}.nc'))} has been saved OK ...")
    
        [fname.unlink(missing_ok=False) for fname in lfiles] 
    
    dset.close()
# Out:
# downloading and processing 1981 05
# 2020-09-05 22:56:29,416 INFO Welcome to the CDS
# 2020-09-05 22:56:29,416 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/seasonal-monthly-single-levels
# 2020-09-05 22:57:08,968 INFO Request is completed
# 2020-09-05 22:57:08,969 INFO Downloading http://136.156.133.46/cache-compute-0015/cache/data5/adaptor.mars.external-1599302625.264087-20230-38-b7acc430-485c-4026-89cd-ede22bac93e6.nc to /media/nicolasf/END19101/data/GCMs/downloads/ECMWF/TMEAN/download_1.nc (3.1M)
# 2020-09-05 22:57:15,940 INFO Download rate 456.9K/s
# 2020-09-05 22:57:46,447 WARNING DELETE https://cds.climate.copernicus.eu/api/v2/tasks/0eb6bd10-898c-48aa-b457-124d5a0b4544 returns 504 Gateway Time-out
# 2020-09-05 22:57:47,678 INFO Welcome to the CDS
# 2020-09-05 22:57:47,680 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/seasonal-monthly-single-levels
# ...

# %%
# dset = xr.open_mfdataset(lfiles, concat_dim=['time'], combine='nested') 

# dset = dset.rename({'time':'step'})

# dset['time'] = (('time'), [datetime(year,month,1)])

# %%
# dset

# %%
# dset.to_netcdf(opath.joinpath(f'CDS_ECMWF_TMEAN_{year}_{str(month).zfill(2)}.nc'))

# if opath.joinpath(f'CDS_ECMWF_PRECIP_{year}_{str(month).zfill(2)}.nc').exists(): 
#     print(f"{str(opath.joinpath(f'CDS_ECMWF_TMEAN_{year}_{str(month).zfill(2)}.nc'))} has been saved OK ...")

#     [fname.unlink(missing_ok=False) for fname in lfiles]
