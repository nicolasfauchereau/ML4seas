# %% [markdown]
# # Python code to download the NOAA ERSST version 5 monthly SST dataset, uses `requests`

# %%
# %matplotlib inline

# %%
import sys

# %%
print(sys.executable)
# Out:
# /home/nicolasf/anaconda3/envs/climlab/bin/python

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
import pathlib
import requests

# %% [markdown]
# ### a small function that returns a list of files given an URL (http) and an extension, uses requests

# %%
def get_url_paths(url, ext='', params={}):
    import requests 
    from bs4 import BeautifulSoup
    response = requests.get(url, params=params)
    if response.ok:
        response_text = response.text
    else:
        return response.raise_for_status()
    soup = BeautifulSoup(response_text, 'html.parser')
    parent = [url + node.get('href') for node in soup.find_all('a') if node.get('href').endswith(ext)]
    return parent

# %% [markdown]
# ### set the local path where the data is / will be downloaded

# %%
local_path = pathlib.Path('./data')

# %%
if not local_path.exists(): 
    local_path.mkdir(parents=True)

# %% [markdown]
# ### set the URL and the location of the datasets on the NOAA server

# %%
base_url = 'https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/'

# %% [markdown]
# ### first get the list of netcdf files currently available

# %%
ext = 'nc'

# %%
remote_files = get_url_paths(base_url, ext)

# %%
remote_files[0]
# Out:
# 'https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/ersst.v5.185401.nc'

# %%
remote_files[-1]
# Out:
# 'https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/ersst.v5.202003.nc'

# %%
remote_files = [f.split('/')[-1] for f in remote_files]

# %% [markdown]
# ### check that the most recent file is not completely outdated

# %%
last_avail = datetime.strptime(f"{remote_files[-1].split('.')[-2]}01", "%Y%m%d")

# %%
lag = (datetime.utcnow() - last_avail).days

# %%
if lag >= 70: 
    print(f"Warning, the last available date on the NOAA server ({last_avail:%Y-%m}) is more than 70 days old ({lag} days ...)")

# %% [markdown]
# ### Now get the list of local files

# %%
local_files  = list(local_path.glob("ersst.*.nc"))

# %%
local_files  = [f.name for f in local_files]

# %% [markdown]
# ### missing files list

# %%
missing_files = list(set(remote_files) - set(local_files))

# %%
missing_files.sort()

# %%
missing_files[0]
# Out:
# 'ersst.v5.185408.nc'

# %%
missing_files[-1]
# Out:
# 'ersst.v5.202003.nc'

# %%
len(missing_files)
# Out:
# 1988

# %% [markdown]
# ### Now loop over the missing files, and download from the NOAA server

# %%
for filename in missing_files: 
    print(f"now trying to download {filename} from {base_url}")
    r = requests.get(f"{base_url}/{filename}") 
    if r.status_code == 200:
        with open(local_path.joinpath(filename), 'wb') as f:
            f.write(r.content) 
        if local_path.joinpath(filename).exists():
            print(f"{filename} successfully saved in {str(local_path)}")
        else: 
            print(f"{filename} was available remotely but could not be saved locally in {str(local_path)}")
    else: 
        print(f"unable to access {filename} at {base_url}")
# Out:
# now trying to download ersst.v5.185408.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185408.nc successfully saved in data
# now trying to download ersst.v5.185409.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185409.nc successfully saved in data
# now trying to download ersst.v5.185410.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185410.nc successfully saved in data
# now trying to download ersst.v5.185411.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185411.nc successfully saved in data
# now trying to download ersst.v5.185412.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185412.nc successfully saved in data
# now trying to download ersst.v5.185501.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185501.nc successfully saved in data
# now trying to download ersst.v5.185502.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185502.nc successfully saved in data
# now trying to download ersst.v5.185503.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185503.nc successfully saved in data
# now trying to download ersst.v5.185504.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185504.nc successfully saved in data
# now trying to download ersst.v5.185505.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185505.nc successfully saved in data
# now trying to download ersst.v5.185506.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185506.nc successfully saved in data
# now trying to download ersst.v5.185507.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185507.nc successfully saved in data
# now trying to download ersst.v5.185508.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185508.nc successfully saved in data
# now trying to download ersst.v5.185509.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185509.nc successfully saved in data
# now trying to download ersst.v5.185510.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185510.nc successfully saved in data
# now trying to download ersst.v5.185511.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185511.nc successfully saved in data
# now trying to download ersst.v5.185512.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185512.nc successfully saved in data
# now trying to download ersst.v5.185601.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185601.nc successfully saved in data
# now trying to download ersst.v5.185602.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185602.nc successfully saved in data
# now trying to download ersst.v5.185603.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185603.nc successfully saved in data
# now trying to download ersst.v5.185604.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185604.nc successfully saved in data
# now trying to download ersst.v5.185605.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185605.nc successfully saved in data
# now trying to download ersst.v5.185606.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185606.nc successfully saved in data
# now trying to download ersst.v5.185607.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185607.nc successfully saved in data
# now trying to download ersst.v5.185608.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185608.nc successfully saved in data
# now trying to download ersst.v5.185609.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185609.nc successfully saved in data
# now trying to download ersst.v5.185610.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185610.nc successfully saved in data
# now trying to download ersst.v5.185611.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185611.nc successfully saved in data
# now trying to download ersst.v5.185612.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185612.nc successfully saved in data
# now trying to download ersst.v5.185701.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185701.nc successfully saved in data
# now trying to download ersst.v5.185702.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185702.nc successfully saved in data
# now trying to download ersst.v5.185703.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185703.nc successfully saved in data
# now trying to download ersst.v5.185704.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185704.nc successfully saved in data
# now trying to download ersst.v5.185705.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185705.nc successfully saved in data
# now trying to download ersst.v5.185706.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185706.nc successfully saved in data
# now trying to download ersst.v5.185707.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185707.nc successfully saved in data
# now trying to download ersst.v5.185708.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185708.nc successfully saved in data
# now trying to download ersst.v5.185709.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185709.nc successfully saved in data
# now trying to download ersst.v5.185710.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185710.nc successfully saved in data
# now trying to download ersst.v5.185711.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185711.nc successfully saved in data
# now trying to download ersst.v5.185712.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185712.nc successfully saved in data
# now trying to download ersst.v5.185801.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185801.nc successfully saved in data
# now trying to download ersst.v5.185802.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185802.nc successfully saved in data
# now trying to download ersst.v5.185803.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185803.nc successfully saved in data
# now trying to download ersst.v5.185804.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185804.nc successfully saved in data
# now trying to download ersst.v5.185805.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185805.nc successfully saved in data
# now trying to download ersst.v5.185806.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185806.nc successfully saved in data
# now trying to download ersst.v5.185807.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185807.nc successfully saved in data
# now trying to download ersst.v5.185808.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185808.nc successfully saved in data
# now trying to download ersst.v5.185809.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185809.nc successfully saved in data
# now trying to download ersst.v5.185810.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185810.nc successfully saved in data
# now trying to download ersst.v5.185811.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185811.nc successfully saved in data
# now trying to download ersst.v5.185812.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185812.nc successfully saved in data
# now trying to download ersst.v5.185901.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185901.nc successfully saved in data
# now trying to download ersst.v5.185902.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185902.nc successfully saved in data
# now trying to download ersst.v5.185903.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185903.nc successfully saved in data
# now trying to download ersst.v5.185904.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185904.nc successfully saved in data
# now trying to download ersst.v5.185905.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185905.nc successfully saved in data
# now trying to download ersst.v5.185906.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185906.nc successfully saved in data
# now trying to download ersst.v5.185907.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185907.nc successfully saved in data
# now trying to download ersst.v5.185908.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185908.nc successfully saved in data
# now trying to download ersst.v5.185909.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185909.nc successfully saved in data
# now trying to download ersst.v5.185910.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185910.nc successfully saved in data
# now trying to download ersst.v5.185911.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185911.nc successfully saved in data
# now trying to download ersst.v5.185912.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.185912.nc successfully saved in data
# now trying to download ersst.v5.186001.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186001.nc successfully saved in data
# now trying to download ersst.v5.186002.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186002.nc successfully saved in data
# now trying to download ersst.v5.186003.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186003.nc successfully saved in data
# now trying to download ersst.v5.186004.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186004.nc successfully saved in data
# now trying to download ersst.v5.186005.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186005.nc successfully saved in data
# now trying to download ersst.v5.186006.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186006.nc successfully saved in data
# now trying to download ersst.v5.186007.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186007.nc successfully saved in data
# now trying to download ersst.v5.186008.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186008.nc successfully saved in data
# now trying to download ersst.v5.186009.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186009.nc successfully saved in data
# now trying to download ersst.v5.186010.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186010.nc successfully saved in data
# now trying to download ersst.v5.186011.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186011.nc successfully saved in data
# now trying to download ersst.v5.186012.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186012.nc successfully saved in data
# now trying to download ersst.v5.186101.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186101.nc successfully saved in data
# now trying to download ersst.v5.186102.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186102.nc successfully saved in data
# now trying to download ersst.v5.186103.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186103.nc successfully saved in data
# now trying to download ersst.v5.186104.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186104.nc successfully saved in data
# now trying to download ersst.v5.186105.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186105.nc successfully saved in data
# now trying to download ersst.v5.186106.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186106.nc successfully saved in data
# now trying to download ersst.v5.186107.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186107.nc successfully saved in data
# now trying to download ersst.v5.186108.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186108.nc successfully saved in data
# now trying to download ersst.v5.186109.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186109.nc successfully saved in data
# now trying to download ersst.v5.186110.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186110.nc successfully saved in data
# now trying to download ersst.v5.186111.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186111.nc successfully saved in data
# now trying to download ersst.v5.186112.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186112.nc successfully saved in data
# now trying to download ersst.v5.186201.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186201.nc successfully saved in data
# now trying to download ersst.v5.186202.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186202.nc successfully saved in data
# now trying to download ersst.v5.186203.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186203.nc successfully saved in data
# now trying to download ersst.v5.186204.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186204.nc successfully saved in data
# now trying to download ersst.v5.186205.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186205.nc successfully saved in data
# now trying to download ersst.v5.186206.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186206.nc successfully saved in data
# now trying to download ersst.v5.186207.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186207.nc successfully saved in data
# now trying to download ersst.v5.186208.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186208.nc successfully saved in data
# now trying to download ersst.v5.186209.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186209.nc successfully saved in data
# now trying to download ersst.v5.186210.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186210.nc successfully saved in data
# now trying to download ersst.v5.186211.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186211.nc successfully saved in data
# now trying to download ersst.v5.186212.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186212.nc successfully saved in data
# now trying to download ersst.v5.186301.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186301.nc successfully saved in data
# now trying to download ersst.v5.186302.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186302.nc successfully saved in data
# now trying to download ersst.v5.186303.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186303.nc successfully saved in data
# now trying to download ersst.v5.186304.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186304.nc successfully saved in data
# now trying to download ersst.v5.186305.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186305.nc successfully saved in data
# now trying to download ersst.v5.186306.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186306.nc successfully saved in data
# now trying to download ersst.v5.186307.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186307.nc successfully saved in data
# now trying to download ersst.v5.186308.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186308.nc successfully saved in data
# now trying to download ersst.v5.186309.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186309.nc successfully saved in data
# now trying to download ersst.v5.186310.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186310.nc successfully saved in data
# now trying to download ersst.v5.186311.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186311.nc successfully saved in data
# now trying to download ersst.v5.186312.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186312.nc successfully saved in data
# now trying to download ersst.v5.186401.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186401.nc successfully saved in data
# now trying to download ersst.v5.186402.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186402.nc successfully saved in data
# now trying to download ersst.v5.186403.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186403.nc successfully saved in data
# now trying to download ersst.v5.186404.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186404.nc successfully saved in data
# now trying to download ersst.v5.186405.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186405.nc successfully saved in data
# now trying to download ersst.v5.186406.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186406.nc successfully saved in data
# now trying to download ersst.v5.186407.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186407.nc successfully saved in data
# now trying to download ersst.v5.186408.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186408.nc successfully saved in data
# now trying to download ersst.v5.186409.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186409.nc successfully saved in data
# now trying to download ersst.v5.186410.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186410.nc successfully saved in data
# now trying to download ersst.v5.186411.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186411.nc successfully saved in data
# now trying to download ersst.v5.186412.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186412.nc successfully saved in data
# now trying to download ersst.v5.186501.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186501.nc successfully saved in data
# now trying to download ersst.v5.186502.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186502.nc successfully saved in data
# now trying to download ersst.v5.186503.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186503.nc successfully saved in data
# now trying to download ersst.v5.186504.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186504.nc successfully saved in data
# now trying to download ersst.v5.186505.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186505.nc successfully saved in data
# now trying to download ersst.v5.186506.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186506.nc successfully saved in data
# now trying to download ersst.v5.186507.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186507.nc successfully saved in data
# now trying to download ersst.v5.186508.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186508.nc successfully saved in data
# now trying to download ersst.v5.186509.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186509.nc successfully saved in data
# now trying to download ersst.v5.186510.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186510.nc successfully saved in data
# now trying to download ersst.v5.186511.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186511.nc successfully saved in data
# now trying to download ersst.v5.186512.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186512.nc successfully saved in data
# now trying to download ersst.v5.186601.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186601.nc successfully saved in data
# now trying to download ersst.v5.186602.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186602.nc successfully saved in data
# now trying to download ersst.v5.186603.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186603.nc successfully saved in data
# now trying to download ersst.v5.186604.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186604.nc successfully saved in data
# now trying to download ersst.v5.186605.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186605.nc successfully saved in data
# now trying to download ersst.v5.186606.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186606.nc successfully saved in data
# now trying to download ersst.v5.186607.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186607.nc successfully saved in data
# now trying to download ersst.v5.186608.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186608.nc successfully saved in data
# now trying to download ersst.v5.186609.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186609.nc successfully saved in data
# now trying to download ersst.v5.186610.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186610.nc successfully saved in data
# now trying to download ersst.v5.186611.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186611.nc successfully saved in data
# now trying to download ersst.v5.186612.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186612.nc successfully saved in data
# now trying to download ersst.v5.186701.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186701.nc successfully saved in data
# now trying to download ersst.v5.186702.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186702.nc successfully saved in data
# now trying to download ersst.v5.186703.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186703.nc successfully saved in data
# now trying to download ersst.v5.186704.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186704.nc successfully saved in data
# now trying to download ersst.v5.186705.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186705.nc successfully saved in data
# now trying to download ersst.v5.186706.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186706.nc successfully saved in data
# now trying to download ersst.v5.186707.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186707.nc successfully saved in data
# now trying to download ersst.v5.186708.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186708.nc successfully saved in data
# now trying to download ersst.v5.186709.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186709.nc successfully saved in data
# now trying to download ersst.v5.186710.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186710.nc successfully saved in data
# now trying to download ersst.v5.186711.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186711.nc successfully saved in data
# now trying to download ersst.v5.186712.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186712.nc successfully saved in data
# now trying to download ersst.v5.186801.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186801.nc successfully saved in data
# now trying to download ersst.v5.186802.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186802.nc successfully saved in data
# now trying to download ersst.v5.186803.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186803.nc successfully saved in data
# now trying to download ersst.v5.186804.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186804.nc successfully saved in data
# now trying to download ersst.v5.186805.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186805.nc successfully saved in data
# now trying to download ersst.v5.186806.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186806.nc successfully saved in data
# now trying to download ersst.v5.186807.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186807.nc successfully saved in data
# now trying to download ersst.v5.186808.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186808.nc successfully saved in data
# now trying to download ersst.v5.186809.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186809.nc successfully saved in data
# now trying to download ersst.v5.186810.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186810.nc successfully saved in data
# now trying to download ersst.v5.186811.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186811.nc successfully saved in data
# now trying to download ersst.v5.186812.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186812.nc successfully saved in data
# now trying to download ersst.v5.186901.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186901.nc successfully saved in data
# now trying to download ersst.v5.186902.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186902.nc successfully saved in data
# now trying to download ersst.v5.186903.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186903.nc successfully saved in data
# now trying to download ersst.v5.186904.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186904.nc successfully saved in data
# now trying to download ersst.v5.186905.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186905.nc successfully saved in data
# now trying to download ersst.v5.186906.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186906.nc successfully saved in data
# now trying to download ersst.v5.186907.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186907.nc successfully saved in data
# now trying to download ersst.v5.186908.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186908.nc successfully saved in data
# now trying to download ersst.v5.186909.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186909.nc successfully saved in data
# now trying to download ersst.v5.186910.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186910.nc successfully saved in data
# now trying to download ersst.v5.186911.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186911.nc successfully saved in data
# now trying to download ersst.v5.186912.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.186912.nc successfully saved in data
# now trying to download ersst.v5.187001.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187001.nc successfully saved in data
# now trying to download ersst.v5.187002.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187002.nc successfully saved in data
# now trying to download ersst.v5.187003.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187003.nc successfully saved in data
# now trying to download ersst.v5.187004.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187004.nc successfully saved in data
# now trying to download ersst.v5.187005.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187005.nc successfully saved in data
# now trying to download ersst.v5.187006.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187006.nc successfully saved in data
# now trying to download ersst.v5.187007.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187007.nc successfully saved in data
# now trying to download ersst.v5.187008.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187008.nc successfully saved in data
# now trying to download ersst.v5.187009.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187009.nc successfully saved in data
# now trying to download ersst.v5.187010.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187010.nc successfully saved in data
# now trying to download ersst.v5.187011.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187011.nc successfully saved in data
# now trying to download ersst.v5.187012.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187012.nc successfully saved in data
# now trying to download ersst.v5.187101.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187101.nc successfully saved in data
# now trying to download ersst.v5.187102.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187102.nc successfully saved in data
# now trying to download ersst.v5.187103.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187103.nc successfully saved in data
# now trying to download ersst.v5.187104.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187104.nc successfully saved in data
# now trying to download ersst.v5.187105.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187105.nc successfully saved in data
# now trying to download ersst.v5.187106.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187106.nc successfully saved in data
# now trying to download ersst.v5.187107.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187107.nc successfully saved in data
# now trying to download ersst.v5.187108.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187108.nc successfully saved in data
# now trying to download ersst.v5.187109.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187109.nc successfully saved in data
# now trying to download ersst.v5.187110.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187110.nc successfully saved in data
# now trying to download ersst.v5.187111.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187111.nc successfully saved in data
# now trying to download ersst.v5.187112.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187112.nc successfully saved in data
# now trying to download ersst.v5.187201.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187201.nc successfully saved in data
# now trying to download ersst.v5.187202.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187202.nc successfully saved in data
# now trying to download ersst.v5.187203.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187203.nc successfully saved in data
# now trying to download ersst.v5.187204.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187204.nc successfully saved in data
# now trying to download ersst.v5.187205.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187205.nc successfully saved in data
# now trying to download ersst.v5.187206.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187206.nc successfully saved in data
# now trying to download ersst.v5.187207.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187207.nc successfully saved in data
# now trying to download ersst.v5.187208.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187208.nc successfully saved in data
# now trying to download ersst.v5.187209.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187209.nc successfully saved in data
# now trying to download ersst.v5.187210.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187210.nc successfully saved in data
# now trying to download ersst.v5.187211.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187211.nc successfully saved in data
# now trying to download ersst.v5.187212.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187212.nc successfully saved in data
# now trying to download ersst.v5.187301.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187301.nc successfully saved in data
# now trying to download ersst.v5.187302.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187302.nc successfully saved in data
# now trying to download ersst.v5.187303.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187303.nc successfully saved in data
# now trying to download ersst.v5.187304.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187304.nc successfully saved in data
# now trying to download ersst.v5.187305.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187305.nc successfully saved in data
# now trying to download ersst.v5.187306.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187306.nc successfully saved in data
# now trying to download ersst.v5.187307.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187307.nc successfully saved in data
# now trying to download ersst.v5.187308.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187308.nc successfully saved in data
# now trying to download ersst.v5.187309.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187309.nc successfully saved in data
# now trying to download ersst.v5.187310.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187310.nc successfully saved in data
# now trying to download ersst.v5.187311.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187311.nc successfully saved in data
# now trying to download ersst.v5.187312.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187312.nc successfully saved in data
# now trying to download ersst.v5.187401.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187401.nc successfully saved in data
# now trying to download ersst.v5.187402.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187402.nc successfully saved in data
# now trying to download ersst.v5.187403.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187403.nc successfully saved in data
# now trying to download ersst.v5.187404.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187404.nc successfully saved in data
# now trying to download ersst.v5.187405.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187405.nc successfully saved in data
# now trying to download ersst.v5.187406.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187406.nc successfully saved in data
# now trying to download ersst.v5.187407.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187407.nc successfully saved in data
# now trying to download ersst.v5.187408.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187408.nc successfully saved in data
# now trying to download ersst.v5.187409.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187409.nc successfully saved in data
# now trying to download ersst.v5.187410.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187410.nc successfully saved in data
# now trying to download ersst.v5.187411.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187411.nc successfully saved in data
# now trying to download ersst.v5.187412.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187412.nc successfully saved in data
# now trying to download ersst.v5.187501.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187501.nc successfully saved in data
# now trying to download ersst.v5.187502.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187502.nc successfully saved in data
# now trying to download ersst.v5.187503.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187503.nc successfully saved in data
# now trying to download ersst.v5.187504.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187504.nc successfully saved in data
# now trying to download ersst.v5.187505.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187505.nc successfully saved in data
# now trying to download ersst.v5.187506.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187506.nc successfully saved in data
# now trying to download ersst.v5.187507.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187507.nc successfully saved in data
# now trying to download ersst.v5.187508.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187508.nc successfully saved in data
# now trying to download ersst.v5.187509.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187509.nc successfully saved in data
# now trying to download ersst.v5.187510.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187510.nc successfully saved in data
# now trying to download ersst.v5.187511.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187511.nc successfully saved in data
# now trying to download ersst.v5.187512.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187512.nc successfully saved in data
# now trying to download ersst.v5.187601.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187601.nc successfully saved in data
# now trying to download ersst.v5.187602.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187602.nc successfully saved in data
# now trying to download ersst.v5.187603.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187603.nc successfully saved in data
# now trying to download ersst.v5.187604.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187604.nc successfully saved in data
# now trying to download ersst.v5.187605.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187605.nc successfully saved in data
# now trying to download ersst.v5.187606.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187606.nc successfully saved in data
# now trying to download ersst.v5.187607.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187607.nc successfully saved in data
# now trying to download ersst.v5.187608.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187608.nc successfully saved in data
# now trying to download ersst.v5.187609.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187609.nc successfully saved in data
# now trying to download ersst.v5.187610.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187610.nc successfully saved in data
# now trying to download ersst.v5.187611.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187611.nc successfully saved in data
# now trying to download ersst.v5.187612.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187612.nc successfully saved in data
# now trying to download ersst.v5.187701.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187701.nc successfully saved in data
# now trying to download ersst.v5.187702.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187702.nc successfully saved in data
# now trying to download ersst.v5.187703.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187703.nc successfully saved in data
# now trying to download ersst.v5.187704.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187704.nc successfully saved in data
# now trying to download ersst.v5.187705.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187705.nc successfully saved in data
# now trying to download ersst.v5.187706.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187706.nc successfully saved in data
# now trying to download ersst.v5.187707.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187707.nc successfully saved in data
# now trying to download ersst.v5.187708.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187708.nc successfully saved in data
# now trying to download ersst.v5.187709.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187709.nc successfully saved in data
# now trying to download ersst.v5.187710.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187710.nc successfully saved in data
# now trying to download ersst.v5.187711.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187711.nc successfully saved in data
# now trying to download ersst.v5.187712.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187712.nc successfully saved in data
# now trying to download ersst.v5.187801.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187801.nc successfully saved in data
# now trying to download ersst.v5.187802.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187802.nc successfully saved in data
# now trying to download ersst.v5.187803.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187803.nc successfully saved in data
# now trying to download ersst.v5.187804.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187804.nc successfully saved in data
# now trying to download ersst.v5.187805.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187805.nc successfully saved in data
# now trying to download ersst.v5.187806.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187806.nc successfully saved in data
# now trying to download ersst.v5.187807.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187807.nc successfully saved in data
# now trying to download ersst.v5.187808.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187808.nc successfully saved in data
# now trying to download ersst.v5.187809.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187809.nc successfully saved in data
# now trying to download ersst.v5.187810.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187810.nc successfully saved in data
# now trying to download ersst.v5.187811.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187811.nc successfully saved in data
# now trying to download ersst.v5.187812.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187812.nc successfully saved in data
# now trying to download ersst.v5.187901.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187901.nc successfully saved in data
# now trying to download ersst.v5.187902.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187902.nc successfully saved in data
# now trying to download ersst.v5.187903.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187903.nc successfully saved in data
# now trying to download ersst.v5.187904.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187904.nc successfully saved in data
# now trying to download ersst.v5.187905.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187905.nc successfully saved in data
# now trying to download ersst.v5.187906.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187906.nc successfully saved in data
# now trying to download ersst.v5.187907.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187907.nc successfully saved in data
# now trying to download ersst.v5.187908.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187908.nc successfully saved in data
# now trying to download ersst.v5.187909.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187909.nc successfully saved in data
# now trying to download ersst.v5.187910.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187910.nc successfully saved in data
# now trying to download ersst.v5.187911.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187911.nc successfully saved in data
# now trying to download ersst.v5.187912.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.187912.nc successfully saved in data
# now trying to download ersst.v5.188001.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188001.nc successfully saved in data
# now trying to download ersst.v5.188002.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188002.nc successfully saved in data
# now trying to download ersst.v5.188003.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188003.nc successfully saved in data
# now trying to download ersst.v5.188004.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188004.nc successfully saved in data
# now trying to download ersst.v5.188005.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188005.nc successfully saved in data
# now trying to download ersst.v5.188006.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188006.nc successfully saved in data
# now trying to download ersst.v5.188007.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188007.nc successfully saved in data
# now trying to download ersst.v5.188008.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188008.nc successfully saved in data
# now trying to download ersst.v5.188009.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188009.nc successfully saved in data
# now trying to download ersst.v5.188010.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188010.nc successfully saved in data
# now trying to download ersst.v5.188011.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188011.nc successfully saved in data
# now trying to download ersst.v5.188012.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188012.nc successfully saved in data
# now trying to download ersst.v5.188101.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188101.nc successfully saved in data
# now trying to download ersst.v5.188102.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188102.nc successfully saved in data
# now trying to download ersst.v5.188103.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.188103.nc successfully saved in data
# ...
# ersst.v5.201105.nc successfully saved in data
# now trying to download ersst.v5.201106.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201106.nc successfully saved in data
# now trying to download ersst.v5.201107.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201107.nc successfully saved in data
# now trying to download ersst.v5.201108.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201108.nc successfully saved in data
# now trying to download ersst.v5.201109.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201109.nc successfully saved in data
# now trying to download ersst.v5.201110.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201110.nc successfully saved in data
# now trying to download ersst.v5.201111.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201111.nc successfully saved in data
# now trying to download ersst.v5.201112.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201112.nc successfully saved in data
# now trying to download ersst.v5.201201.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201201.nc successfully saved in data
# now trying to download ersst.v5.201202.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201202.nc successfully saved in data
# now trying to download ersst.v5.201203.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201203.nc successfully saved in data
# now trying to download ersst.v5.201204.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201204.nc successfully saved in data
# now trying to download ersst.v5.201205.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201205.nc successfully saved in data
# now trying to download ersst.v5.201206.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201206.nc successfully saved in data
# now trying to download ersst.v5.201207.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201207.nc successfully saved in data
# now trying to download ersst.v5.201208.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201208.nc successfully saved in data
# now trying to download ersst.v5.201209.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201209.nc successfully saved in data
# now trying to download ersst.v5.201210.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201210.nc successfully saved in data
# now trying to download ersst.v5.201211.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201211.nc successfully saved in data
# now trying to download ersst.v5.201212.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201212.nc successfully saved in data
# now trying to download ersst.v5.201301.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201301.nc successfully saved in data
# now trying to download ersst.v5.201302.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201302.nc successfully saved in data
# now trying to download ersst.v5.201303.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201303.nc successfully saved in data
# now trying to download ersst.v5.201304.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201304.nc successfully saved in data
# now trying to download ersst.v5.201305.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201305.nc successfully saved in data
# now trying to download ersst.v5.201306.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201306.nc successfully saved in data
# now trying to download ersst.v5.201307.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201307.nc successfully saved in data
# now trying to download ersst.v5.201308.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201308.nc successfully saved in data
# now trying to download ersst.v5.201309.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201309.nc successfully saved in data
# now trying to download ersst.v5.201310.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201310.nc successfully saved in data
# now trying to download ersst.v5.201311.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201311.nc successfully saved in data
# now trying to download ersst.v5.201312.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201312.nc successfully saved in data
# now trying to download ersst.v5.201401.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201401.nc successfully saved in data
# now trying to download ersst.v5.201402.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201402.nc successfully saved in data
# now trying to download ersst.v5.201403.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201403.nc successfully saved in data
# now trying to download ersst.v5.201404.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201404.nc successfully saved in data
# now trying to download ersst.v5.201405.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201405.nc successfully saved in data
# now trying to download ersst.v5.201406.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201406.nc successfully saved in data
# now trying to download ersst.v5.201407.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201407.nc successfully saved in data
# now trying to download ersst.v5.201408.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201408.nc successfully saved in data
# now trying to download ersst.v5.201409.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201409.nc successfully saved in data
# now trying to download ersst.v5.201410.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201410.nc successfully saved in data
# now trying to download ersst.v5.201411.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201411.nc successfully saved in data
# now trying to download ersst.v5.201412.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201412.nc successfully saved in data
# now trying to download ersst.v5.201501.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201501.nc successfully saved in data
# now trying to download ersst.v5.201502.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201502.nc successfully saved in data
# now trying to download ersst.v5.201503.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201503.nc successfully saved in data
# now trying to download ersst.v5.201504.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201504.nc successfully saved in data
# now trying to download ersst.v5.201505.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201505.nc successfully saved in data
# now trying to download ersst.v5.201506.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201506.nc successfully saved in data
# now trying to download ersst.v5.201507.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201507.nc successfully saved in data
# now trying to download ersst.v5.201508.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201508.nc successfully saved in data
# now trying to download ersst.v5.201509.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201509.nc successfully saved in data
# now trying to download ersst.v5.201510.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201510.nc successfully saved in data
# now trying to download ersst.v5.201511.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201511.nc successfully saved in data
# now trying to download ersst.v5.201512.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201512.nc successfully saved in data
# now trying to download ersst.v5.201601.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201601.nc successfully saved in data
# now trying to download ersst.v5.201602.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201602.nc successfully saved in data
# now trying to download ersst.v5.201603.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201603.nc successfully saved in data
# now trying to download ersst.v5.201604.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201604.nc successfully saved in data
# now trying to download ersst.v5.201605.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201605.nc successfully saved in data
# now trying to download ersst.v5.201606.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201606.nc successfully saved in data
# now trying to download ersst.v5.201607.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201607.nc successfully saved in data
# now trying to download ersst.v5.201608.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201608.nc successfully saved in data
# now trying to download ersst.v5.201609.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201609.nc successfully saved in data
# now trying to download ersst.v5.201610.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201610.nc successfully saved in data
# now trying to download ersst.v5.201611.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201611.nc successfully saved in data
# now trying to download ersst.v5.201612.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201612.nc successfully saved in data
# now trying to download ersst.v5.201701.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201701.nc successfully saved in data
# now trying to download ersst.v5.201702.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201702.nc successfully saved in data
# now trying to download ersst.v5.201703.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201703.nc successfully saved in data
# now trying to download ersst.v5.201704.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201704.nc successfully saved in data
# now trying to download ersst.v5.201705.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201705.nc successfully saved in data
# now trying to download ersst.v5.201706.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201706.nc successfully saved in data
# now trying to download ersst.v5.201707.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201707.nc successfully saved in data
# now trying to download ersst.v5.201708.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201708.nc successfully saved in data
# now trying to download ersst.v5.201709.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201709.nc successfully saved in data
# now trying to download ersst.v5.201710.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201710.nc successfully saved in data
# now trying to download ersst.v5.201711.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201711.nc successfully saved in data
# now trying to download ersst.v5.201712.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201712.nc successfully saved in data
# now trying to download ersst.v5.201801.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201801.nc successfully saved in data
# now trying to download ersst.v5.201802.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201802.nc successfully saved in data
# now trying to download ersst.v5.201803.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201803.nc successfully saved in data
# now trying to download ersst.v5.201804.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201804.nc successfully saved in data
# now trying to download ersst.v5.201805.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201805.nc successfully saved in data
# now trying to download ersst.v5.201806.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201806.nc successfully saved in data
# now trying to download ersst.v5.201807.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201807.nc successfully saved in data
# now trying to download ersst.v5.201808.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201808.nc successfully saved in data
# now trying to download ersst.v5.201809.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201809.nc successfully saved in data
# now trying to download ersst.v5.201810.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201810.nc successfully saved in data
# now trying to download ersst.v5.201811.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201811.nc successfully saved in data
# now trying to download ersst.v5.201812.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201812.nc successfully saved in data
# now trying to download ersst.v5.201901.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201901.nc successfully saved in data
# now trying to download ersst.v5.201902.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201902.nc successfully saved in data
# now trying to download ersst.v5.201903.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201903.nc successfully saved in data
# now trying to download ersst.v5.201904.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201904.nc successfully saved in data
# now trying to download ersst.v5.201905.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201905.nc successfully saved in data
# now trying to download ersst.v5.201906.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201906.nc successfully saved in data
# now trying to download ersst.v5.201907.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201907.nc successfully saved in data
# now trying to download ersst.v5.201908.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201908.nc successfully saved in data
# now trying to download ersst.v5.201909.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201909.nc successfully saved in data
# now trying to download ersst.v5.201910.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201910.nc successfully saved in data
# now trying to download ersst.v5.201911.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201911.nc successfully saved in data
# now trying to download ersst.v5.201912.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.201912.nc successfully saved in data
# now trying to download ersst.v5.202001.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.202001.nc successfully saved in data
# now trying to download ersst.v5.202002.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.202002.nc successfully saved in data
# now trying to download ersst.v5.202003.nc from https://www1.ncdc.noaa.gov/pub/data/cmb/ersst/v5/netcdf/
# ersst.v5.202003.nc successfully saved in data
